# %%
print(type(2))
# Out:
# <class 'int'>

# %%
print(type(2.0))
# Out:
# <class 'float'>

# %% [markdown]
# logical  oprator

# %%
print(type("anuj"))
# Out:
# <class 'str'>

# %%
x="anuj "

print(x.strip())
# Out:
# anuj

# %%
print(x.rstrip())
# Out:
# anuj

# %%
x= True
y=False
print(x and y)
# Out:
# False

# %%
print(x or y)
# Out:
# True

# %%
print (not x==y)
# Out:
# True
