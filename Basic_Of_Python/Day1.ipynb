# %%
print(type(2))
# Out:
# <class 'int'>

# %%
print(type(2.0))
# Out:
# <class 'float'>

# %% [markdown]
# logical  oprator

# %%
print(type("anuj"))
# Out:
# <class 'str'>

# %%
x="anuj "

print(x.strip())
# Out:
# anuj

# %%
print(x.rstrip())
# Out:
# anuj

# %%
x= True
y=False
print(x and y)
# Out:
# False

# %%
print(x or y)
# Out:
# True

# %%
print (not x==y)
# Out:
# True

# %% [markdown]
# what is  string method and opratort

# %%
x=" anuj kumar "
x=x.lstrip().rstrip()
print(x)
# Out:
# anuj kumar

# %%
x=input("Enter The  Ascess code")
code =len(x)

if code>=4:
    print("Thanks Allow")
else:
    print("security Alert , not allow  please enter correct code")
# Out:
# security Alert , not allow  please enter correct code
