# %% [markdown]
# Qestion :1

# %%
# x=input("Enter The  Ascess code")
# code =len(x)

# if code>=4 and code:
#     print("Thanks Allow")
# else:
#     print("security Alert , not allow  please enter correct code")
# Out:
# security Alert , not allow  please enter correct code

# %% [markdown]
# QUestion 2:

# %%
# x=int(input("Enter the number of egg:"))
# if x>3:
#     print("Ok no need to go market")
# else:
#     print("we have need to go market")
# Out:
# we have need to go market

# %% [markdown]
# Question 3:

# %%
# x=input("check AC is of/ on")
# y=input("check cuffe machin is of/on")
# z=input("check the main door in clocked aur ubncloced")
# if x=="yes":
#     print("you AC is off")
# else:
#     print("your AC is not off please of  it")
# if y=="yes":
#       print("you coffe is off")
# else:
#     print("your cofee is not off please of  it")

# if z=="yes":
#       print("you door is off")
# else:
#     print("your door is not off please of  it")
# Out:
# you AC is off
# you coffe is off
# your door is not off please of  it

# %% [markdown]
# Question 4 :

# %%
# extra_chese=bool(input("Enter the chease"))
# peper_oni=bool(input("Enter the oni"))
# olivess=bool(input("Enter the olive"))
# print(olivess)
# totoL_prize=10
# if extra_chese:
#     totoL_prize+=2
# if peper_oni:
#     totoL_prize+=3
# if olivess:
#     totoL_prize+=4
# print(totoL_prize)
# Out:
# False
# 13

# %% [markdown]
# Question 5:

# %%
# color=input("Enter the color please:")
# if color=="Red":
#     print("please stop and wait for yellow")
# elif color=="yellow":
#     print("ready for green")
# elif color=="green":
#     print("you can cross the terminal or road")
# else:
#     print("You Entered the wrong color")
# Out:
# you can cross the terminal or road

# %% [markdown]
# Question 6:

# %%
# age=int(input("Enter the age first:"))

# if age<5:
#     print("child ticket is free")
# elif age>=5 and age<=7:
#     print(r"ticket fee is :{10}")
# elif age>=18 and age<=60:
#     print(r"ticket is :{18}")
# else:
#     print("sernor ticket is more the 100$")
# Out:
# ticket fee is :{10}

# %% [markdown]
# Question 7

# %%
# steps=[400,500,6000,4000]
# x=1
# for i in  steps:
#     print(f" Day {x}:" , i)
#     x+=1
# Out:
#  Day 1: 400
#  Day 2: 500
#  Day 3: 6000
#  Day 4: 4000

# %% [markdown]
# Question 8

# %%
client_Name=["anuj","praveen","alok","nitish"]
for x in client_Name:
    print(f" {x.upper()}: HI you all get good promo code so consgratulation for you all")
# Out:
#  ANUJ: HI you all get good promo code so consgratulation for you all
#  PRAVEEN: HI you all get good promo code so consgratulation for you all
#  ALOK: HI you all get good promo code so consgratulation for you all
#  NITISH: HI you all get good promo code so consgratulation for you all
