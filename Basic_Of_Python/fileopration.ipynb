# %% [markdown]
# File Opration

# %%
import os
cd =os.getcwd()
print(cd)
total_folder= os.listdir("D:/abhishck")
count =0
for extantion in total_folder:
    # extensions= list(extantion)
    print(extantion)
    extension= extantion.split(".")[-1]
    print(extension)
    if  extension=="ipynb":
        count+=1    
print(count)
# Out:
# c:\Users\anuj.kumar\Documents\AI-Engineer\Basic_Of_Python
# addlink.py
# py
# addlinks.py
# py
# alt_checkup (1).js
# js
# alt_filter.py
# py
# AshishLinking.py
# py
# imageExtarct.py
# py
# index.js
# js
# indexs.js
# js
# linking_SMP_Vocab.js
# js
# node_modules
# node_modules
# package-lock.json
# json
# package.json
# json
# report.js
# js
# TEHNM.docx
# docx
# TEHNM.js
# js
# upadted.py
# py
# video_report.xlsx
# xlsx
# video_reports.xlsx
# xlsx
# video_report_with_links.xlsx
# xlsx
# ~$TEHNM.docx
# docx
# ~$video_report.xlsx
# xlsx
# 0

# %%
# import os
# origina_path="D:/abhishck"
# for root ,dir, files in os.walk(origina_path):
#     print("this root folderL:", root)
#     print("this is the dir:",dir)
#     print("this is all file under the folder :", files)
# Out:
# this root folderL: D:/abhishck
# this is the dir: ['node_modules']
# this is all file under the folder : ['addlink.py', 'addlinks.py', 'alt_checkup (1).js', 'alt_filter.py', 'AshishLinking.py', 'imageExtarct.py', 'index.js', 'indexs.js', 'linking_SMP_Vocab.js', 'package-lock.json', 'package.json', 'report.js', 'TEHNM.docx', 'TEHNM.js', 'upadted.py', 'video_report.xlsx', 'video_reports.xlsx', 'video_report_with_links.xlsx', '~$TEHNM.docx', '~$video_report.xlsx']
# this root folderL: D:/abhishck\node_modules
# ...

# %%
import os
f=open("myself.text")
value=f.readlines()
print(value)
value=f.readline()
print(value)
f.close()
# Out:
# ["HI I'm anuj kumar  from natha chapra \n", "right i'm woing as software engineer at magic software \n", 'I have  total 2+ years of experince in domian of  fullStack and  in ai \n', '\n']
# ["HI I'm anuj kumar  from natha chapra \n", "right i'm woing as software engineer at magic software \n", 'I have  total 2+ years of experince in domian of  fullStack and  in ai \n', '\n']

# %%
import os
f=open("myself.text")
value=f.readlines()
print(value)
for line in value:
    actualLine=line.rstrip() 
    print(actualLine)
f.close()

import os
cd =os.getcwd
toatal_file= os.listdir()
print(toatal_file)
for file in toatal_file:
    print(file)
    fileExtantion=file.split(".")[-1]
    if fileExtantion=="text":
        f=open(file)
        conatnat=f.readlines()
        for line  in conatnat:
           print(line.strip())
           f.close()
# Out:
# ['anuj', 'Assignmet1.ipynb', 'Day1.ipynb', 'Day1.md', 'fileopration.ipynb', 'myself.text', 'practice.ipynb']
# anuj
# Assignmet1.ipynb
# Day1.ipynb
# Day1.md
# fileopration.ipynb
# myself.text
# HI I'm anuj kumar  from natha chapra
# right i'm woing as software engineer at magic software
# I have  total 2+ years of experince in domian of  fullStack and  in ai
#
# practice.ipynb

# %%
import os
with open("myself.text","r") as f:
   print(f.tell())
   print(f.seek(0))
   contant= f.read()
   print(contant)
   print(f.tell())
# Out:
# 0
# i'm anuj from natha chapra
# right i'm woing as software engineer at magic software
# I have  total 2+ years of experince in domian of  fullStack and  in  my name is anuj kumar
# 176

# %% [markdown]
# Here  the file  opration
# r=> this is one used to read the file  only if you file is not exsting itis gving erro
# r+(read+ write) it start radding 0 pinter and aslo write somthing at end  of thing  it aslo need to must have file in tour folder
#
#
# w=>  this is one start to write from top of   the pointer and  begain from at 0  and if file is not exsinting it also able create  but it overwrite your old data and you can delte
# w+  this mode (write +read) first sstrt write from begaining and once it end then  it write  it aslo craete  file if file is not found but cons is that it also overwrite your original data..
#
#
# a=> this is one is used to apend the data at end of teh fiel whare previous data is end
#
# a+ this is one is mode is also help to apned the data from end and satrt reading aslo from the end wherre it start the apendingng must have  data and
# f.tell()=>it telliig the whereis pointer  now wheter is beging whether is ending and midile
#
# f.seek()=>it is telling you  that wnhere  you wnt plese your current pointer
#  this is opration is used for  the file oprations

# %%
import os
with open("myself.text","r+") as f:
    Intial_pointer=f.tell()
    print(f.read())
    print(Intial_pointer,Intial_pointer)
    final_contant=f.write("anujkumar")
    Intial_pointer=f.tell()
    print(Intial_pointer,Intial_pointer)
# Out:
# i'm anuj from natha chapra
# right i'm woing as software engineer at magic software
# I have  total 2+ years of experince in domian of  fullStack and  in  anujkumar
# 0 0
# 173 173

# %%
import os
with open("myself.textsj","a") as f:
    print(f.tell())
    f.seek(0)
    # print(f.read())
    f.write("my name is anuj kumar")
    print(f.tell())
    print(f.tell())
# Out:
# 0
# 21
# 21

# %% [markdown]
# write  in the midile of the file without overwriting old  datafrom the file

# %%
import os
with open("myself.text","r+") as f:
    intial_pointer=f.seek(0)
    f.read()
    final_pointer=f.tell()
    mid_pointer=(intial_pointer+ final_pointer)//2
    f.seek(mid_pointer)
    remaing=f.read()
    print(remaing)

    f.write("SOFTWARE AT MAGICEDTECH" + remaing)
    # f.seek(0)
    print(intial_pointer,final_pointer,mid_pointer,  f.tell() ,f.read())
# Out:
# ic software
# I have  total 2+ years of experince in domian of  fullStack and  in
#
# 0 165 82 271
